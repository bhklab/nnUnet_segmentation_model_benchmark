# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import matplotlib.pyplot as plt
import numpy as np
import nibabel as nib

# %%
test_load = nib.load('/content/gdrive/MyDrive/CSC494/img_00_files/benchmark_ad1.nii.gz').get_fdata()
test_load.shape
# Out:
# (320, 320, 38)

# %%
test = test_load[:,:,19]
plt.imshow(test)
plt.show()

# %%
test_load = nib.load('/content/gdrive/MyDrive/CSC494/img_00_files/gyn_0120_label.nii.gz').get_fdata()
test_load[test_load != 4] = 0
test = test_load[:,:,26]
img = np.rot90(test,axes=(-1,-2))
plt.imshow(img)
plt.show()
